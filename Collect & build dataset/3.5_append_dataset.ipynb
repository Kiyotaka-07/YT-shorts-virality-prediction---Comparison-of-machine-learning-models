# %%
import pandas as pd

# %%
dataset_old = pd.read_csv("very_final_dataset.csv")
dataset3 = pd.read_csv('dataset4.csv')

# %%
dataset_new = pd.concat(
    [dataset_old, dataset3],
    ignore_index=True
)

# %%
dataset_new.to_csv(
    "dataset_final_1.csv",
    index=False
)
